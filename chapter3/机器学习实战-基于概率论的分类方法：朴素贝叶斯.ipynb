# %% [markdown]
# ## 1. 基于贝叶斯决策理论的分类方法

# %% [markdown]
# > 优点：在数据较少的情况下仍然有效，可以处理多类别问题
#
# > 缺点：对于输入数据的准备方式较为敏感
#
# > 适用数据类型：标称型数据

# %% [markdown]
# 贝叶斯决策理论的核心思想，就是选择具有最高概率的决策。很合理

# %% [markdown]
# ## 2. 条件概率

# %% [markdown]
# 条件概率就是在已知某一事件发生的条件下计算另一事件的发生概率。
#
# $p\left( c|x\right) =\dfrac {p\left( xc\right)}{p\left( x\right) }$

# %% [markdown]
# 根据先验知识计算后验概率是最精彩的：
#
# $p\left( c|x\right) =\dfrac {p\left( x|c\right) p\left( c\right) }{p\left( x\right) }$

# %% [markdown]
# ## 3. 使用朴素贝叶斯进行文档分类

# %% [markdown]
# 文档的特征往往很多，如果每个特征需要N个样本，那么样本数就会呈指数增长，这个时候需要假设特征间相互独立，那么样本数立马变成线性的了，这也是朴素贝叶斯里*朴素*的来源。

# %% [markdown]
# ## 4. 使用Python进行文本分类

# %% [markdown]
# ### 4.1 准备数据：从文本中构建词向量

# %%
def loadDataSet():
    postingList = [['my', 'dog', 'has', 'flea', 'problems', 'help', 'please'],
                  ['maybe', 'not', 'take', 'him', 'to', 'dog', 'park', 'stupid'],
                  ['my', 'dalmation', 'is', 'so', 'cute', 'I', 'love', 'him'],
                  ['stop', 'posting', 'stupid', 'worthless', 'garbage'],
                  ['mr', 'licks', 'ate', 'my', 'steak', 'how', 'to', 'stop', 'him'],
                  ['quit', 'buying', 'worthless', 'dog', 'food', 'stupid']]
    classVec = [0, 1, 0, 1, 0, 1]
    return postingList, classVec

# %%
def createVocabList(dataSet):
    vocabSet = set()
    for document in dataSet:
        vocabSet = vocabSet | set(document)
    return vocabSet

# %%
def setOfWords2Vec(vocabList, inputSet):
    vocabList = list(vocabList)
    returnVec = [0] * len(vocabList)
    for word in inputSet:
        if word in vocabList:
            returnVec[vocabList.index(word)] = 1
        else:
            print('the word : {0} is not in my Vocabulary!'.format(word))
    return returnVec

# %%
# test
listOPosts, listClasses = loadDataSet()
myVocabList = createVocabList(listOPosts)
myVocabList
# Out:
# {'I',
#  'ate',
#  'buying',
#  'cute',
#  'dalmation',
#  'dog',
#  'flea',
#  'food',
#  'garbage',
#  'has',
#  'help',
#  'him',
#  'how',
#  'is',
#  'licks',
#  'love',
#  'maybe',
#  'mr',
#  'my',
#  'not',
#  'park',
#  'please',
#  'posting',
#  'problems',
#  'quit',
#  'so',
#  'steak',
#  'stop',
#  'stupid',
#  'take',
#  'to',
#  'worthless'}

# %%
setOfWords2Vec(myVocabList, listOPosts[0])[:10]
# Out:
# [0, 0, 0, 1, 0, 0, 0, 0, 0, 1]

# %% [markdown]
# ### 4.2 训练算法：从词向量计算概率

# %%
import numpy as np

# %%
# 训练函数
def trainNB0(trainMatrix, trainCategory):
    numTrainDocs = len(trainMatrix)
    numWords = len(trainMatrix[0])
    pAbusive = np.sum(trainCategory)/numTrainDocs
    p0Num = np.zeros(numWords)
    p1Num = np.zeros(numWords)
    p0Denom = 0.0
    p1Denom = 0.0
    for i in range(numTrainDocs):
        if trainCategory[i] == 1:
            p1Num += trainMatrix[i]
            p1Denom += np.sum(trainMatrix[i])
        else:
            p0Num += trainMatrix[i]
            p0Denom += np.sum(trainMatrix[i])
    p1Vect = p1Num/p1Denom
    p0Vect = p0Num/p0Denom
    return p0Vect, p1Vect, pAbusive

# %%
trainMat = []
for postingDoc in listOPosts:
    trainMat.append(setOfWords2Vec(myVocabList, postingDoc))

p0V, p1V, pAb = trainNB0(trainMat, listClasses)

# %%
p0V
# Out:
# array([ 0.        ,  0.04166667,  0.04166667,  0.04166667,  0.        ,
#         0.04166667,  0.        ,  0.04166667,  0.        ,  0.04166667,
#         0.04166667,  0.04166667,  0.08333333,  0.04166667,  0.04166667,
#         0.04166667,  0.04166667,  0.        ,  0.04166667,  0.        ,
#         0.04166667,  0.04166667,  0.04166667,  0.        ,  0.04166667,
#         0.125     ,  0.        ,  0.04166667,  0.04166667,  0.        ,
#         0.        ,  0.        ])

# %%
p1V
# Out:
# array([ 0.05263158,  0.        ,  0.        ,  0.        ,  0.05263158,
#         0.        ,  0.05263158,  0.        ,  0.05263158,  0.        ,
#         0.        ,  0.05263158,  0.05263158,  0.        ,  0.        ,
#         0.10526316,  0.05263158,  0.05263158,  0.        ,  0.05263158,
#         0.        ,  0.        ,  0.        ,  0.10526316,  0.        ,
#         0.        ,  0.05263158,  0.        ,  0.        ,  0.05263158,
#         0.05263158,  0.15789474])

# %%
pAb
# Out:
# 0.5

# %% [markdown]
# ### 4.3 测试算法：根据现实情况修改分类器

# %% [markdown]
# 利用贝叶斯分类器进行文档分类时，要计算多个概率的乘积，如果其中一个概率为0，则最后乘积也为0，为避免这种影响，初始化应该修改。
#
# 另一个问题是如果太多很小的数相乘或造成下溢出，这时候可采取取对数的方法，同时将乘法转变成加法。

# %%
def trainNB0(trainMatrix, trainCategory):
    numTrainDocs = len(trainMatrix)
    numWords = len(trainMatrix[0])
    pAbusive = np.sum(trainCategory)/numTrainDocs
    p0Num = np.ones(numWords)
    p1Num = np.ones(numWords)
    p0Denom = 2.0
    p1Denom = 2.0
    for i in range(numTrainDocs):
        if trainCategory[i] == 1:
            p1Num += trainMatrix[i]
            p1Denom += np.sum(trainMatrix[i])
        else:
            p0Num += trainMatrix[i]
            p0Denom += np.sum(trainMatrix[i])
    p1Vect = np.log(p1Num/p1Denom)
    p0Vect = np.log(p0Num/p0Denom)
    return p0Vect, p1Vect, pAbusive

# %%
def classifyNB(vec2Classify, p0Vec, p1Vec, pClass1):
    p1 = np.sum(vec2Classify * p1Vec) + np.log(pClass1)
    p0 = np.sum(vec2Classify * p0Vec) + np.log(1.0 - pClass1)
    if p1 > p0:
        return 1
    else:
        return 0

# %%
def testingNB():
    listOPosts, listClasses = loadDataSet()
    myVocabList = createVocabList(listOPosts)
    trainMat = []
    for postingDoc in listOPosts:
        trainMat.append(setOfWords2Vec(myVocabList, postingDoc))
    p0V, p1V, pAb = trainNB0(np.array(trainMat), np.array(listClasses))
    testEntry = ['love', 'my', 'dalmation']
    thisDoc = np.array(setOfWords2Vec(myVocabList, testEntry))
    print('{0} classified as: {1}'.format(testEntry, classifyNB(thisDoc, p0V, p1V, pAb)))
    testEntry = ['stupid', 'garbage']
    thisDoc = np.array(setOfWords2Vec(myVocabList, testEntry))
    print('{0} classified as: {1}'.format(testEntry, classifyNB(thisDoc, p0V, p1V, pAb)))

# %%
testingNB()
# Out:
# ['love', 'my', 'dalmation'] classified as: 0
# ['stupid', 'garbage'] classified as: 1

# %% [markdown]
# ### 4.4 准备数据：文档词袋模型

# %% [markdown]
# 上面我们将每个词的是否出现作为一个特征，这个叫**词集模型**，如果一个词在文档中出现不止一次，这可能包含更多的信息，这叫做**词袋模型**，修改起来也是比较容易的。

# %%
def bagOfWordVecMN(vocabList, inputSet):
    vocabList = list(vocabList)
    returnVec = [0] * len(vocabList)
    for word in inputSet:
        if word in vocabList:
            returnVec[vocabList.index(word)] += 1
    return returnVec

# %% [markdown]
# ## 5. 示例：使用朴素贝叶斯过滤垃圾邮件

# %% [markdown]
# ### 5.1 准备数据：切分文本

# %%
mySent = 'This book is the best book on Python or M.L. I have ever laid eye upon.'
mySent.split()
# Out:
# ['This',
#  'book',
#  'is',
#  'the',
#  'best',
#  'book',
#  'on',
#  'Python',
#  'or',
#  'M.L.',
#  'I',
#  'have',
#  'ever',
#  'laid',
#  'eye',
#  'upon.']

# %% [markdown]
# 切分效果不错，但是标点符号也被当成了词的一部分。

# %%
import re
regEx = re.compile('\\W*')
listOfTokens = regEx.split(mySent)
listOfTokens
# Out:
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: split() requires a non-empty pattern match.
#   This is separate from the ipykernel package so we can avoid doing imports until
# ['This',
#  'book',
#  'is',
#  'the',
#  'best',
#  'book',
#  'on',
#  'Python',
#  'or',
#  'M',
#  'L',
#  'I',
#  'have',
#  'ever',
#  'laid',
#  'eye',
#  'upon',
#  '']

# %% [markdown]
# 存在空字符

# %%
[tok.lower() for tok in listOfTokens if len(tok) > 0]
# Out:
# ['this',
#  'book',
#  'is',
#  'the',
#  'best',
#  'book',
#  'on',
#  'python',
#  'or',
#  'm',
#  'l',
#  'i',
#  'have',
#  'ever',
#  'laid',
#  'eye',
#  'upon']

# %% [markdown]
# ### 5.2 测试算法：使用朴素贝叶斯进行交叉验证

# %%
def textParse(bigString):
    import re
    listOfTokens = re.split(r'\W*', bigString)
    return [tok.lower() for tok in listOfTokens if len(tok) > 2]

# %%
def spamTest():
    docList = []
    classList = []
    fullText = []
    for i in range(1, 26):
        wordList = textParse(open('email/spam/{0}.txt'.format(i)).read())
        docList.append(wordList)
        fullText.extend(wordList)
        classList.append(1)
        wordList = textParse(open('email/ham/{0}.txt'.format(i)).read())
        docList.append(wordList)
        fullText.extend(wordList)
        classList.append(0)
    vocabList = createVocabList(docList)
    trainingSet = list(range(50))
    testSet = []
    for i in range(10):
        randIndex = int(np.random.uniform(0, len(trainingSet)))
        testSet.append(trainingSet[randIndex])
        del trainingSet[randIndex]
    trainMat = []
    trainClasses = []
    for docIndex in trainingSet:
        trainMat.append(setOfWords2Vec(vocabList, docList[docIndex]))
        trainClasses.append(classList[docIndex])
    p0V, p1V, pSpam = trainNB0(np.array(trainMat), np.array(trainClasses))
    errorCount = 0
    for docIndex in testSet:
        wordVector = setOfWords2Vec(vocabList, docList[docIndex])
        if classifyNB(np.array(wordVector), p0V, p1V, pSpam) != classList[docIndex]:
            errorCount += 1
    print('the error rate is: {}'.format(errorCount/len(testSet)))

# %%
spamTest()
# Out:
# the error rate is: 0.1
# E:\Anaconda3\lib\re.py:212: FutureWarning: split() requires a non-empty pattern match.
#   return _compile(pattern, flags).split(string, maxsplit)

# %% [markdown]
# ## 6. 示例：使用朴素贝叶斯分类器从个人广告中获取区域倾向

# %% [markdown]
# ### 6.1 收集数据：导入RSS源

# %%
import feedparser

# %%
ny = feedparser.parse('https://www.craigslist.org/about/best/all/index.rss')
len(ny['entries'])
# Out:
# 25

# %%
ny['entries']
# Out:
# [{'author': 'robot@craigslist.org',
#   'author_detail': {'email': 'robot@craigslist.org'},
#   'authors': [{'email': 'robot@craigslist.org'}],
#   'dc_source': 'https://www.craigslist.org/about/best/tpk/6581431260.html',
#   'dc_type': 'text',
#   'id': 'https://www.craigslist.org/about/best/tpk/6581431260.html',
#   'link': 'https://www.craigslist.org/about/best/tpk/6581431260.html',
#   'links': [{'href': 'https://www.craigslist.org/about/best/tpk/6581431260.html',
#     'rel': 'alternate',
#     'type': 'text/html'}],
#   'rights': 'copyright 2018 craigslist',
#   'rights_detail': {'base': 'https://www.craigslist.org/about/best/all/index.rss',
#    'language': None,
#    'type': 'text/plain',
#    'value': 'copyright 2018 craigslist'},
#   'summary': "1995 Honda CBR 900 RR, very unique.  Yes it is wrapped with wrinke crush velvet.  Slavage title and has a 96 motor in it.  Will need tires.  We've had the bike since 2001. Cross posted.<br>\n<br>",
#   'summary_detail': {'base': 'https://www.craigslist.org/about/best/all/index.rss',
#    'language': None,
#    'type': 'text/html',
#    'value': "1995 Honda CBR 900 RR, very unique.  Yes it is wrapped with wrinke crush velvet.  Slavage title and has a 96 motor in it.  Will need tires.  We've had the bike since 2001. Cross posted.<br>\n<br>"},
#   'title': '95 Honda CBR 900RR',
#   'title_detail': {'base': 'https://www.craigslist.org/about/best/all/index.rss',
#    'language': None,
#    'type': 'text/plain',
#    'value': '95 Honda CBR 900RR'},
#   'updated': '2018-05-06T11:59:40-05:00',
#   'updated_parsed': time.struct_time(tm_year=2018, tm_mon=5, tm_mday=6, tm_hour=16, tm_min=59, tm_sec=40, tm_wday=6, tm_yday=126, tm_isdst=0)},
#  {'author': 'robot@craigslist.org',
#   'author_detail': {'email': 'robot@craigslist.org'},
#   'authors': [{'email': 'robot@craigslist.org'}],
#   'dc_source': 'https://www.craigslist.org/about/best/hou/6565526716.html',
#   'dc_type': 'text',
#   'id': 'https://www.craigslist.org/about/best/hou/6565526716.html',
#   'link': 'https://www.craigslist.org/about/best/hou/6565526716.html',
#   'links': [{'href': 'https://www.craigslist.org/about/best/hou/6565526716.html',
#     'rel': 'alternate',
#     'type': 'text/html'}],
#   'rights': 'copyright 2018 craigslist',
#   'rights_detail': {'base': 'https://www.craigslist.org/about/best/all/index.rss',
#    'language': None,
#    'type': 'text/plain',
#    'value': 'copyright 2018 craigslist'},
#   'summary': 'You want a car that gets the job done? You want a car that\'s hassle free? You want a car that literally no one will ever compliment you on? Well look no further. <br>\n<br>\nThe 1999 Toyota Corolla. <br>\n<br>\nLet\'s talk about features. <br>\nBluetooth: nope<br>\nSunroof: nope<br>\nFancy wheels: nope<br>\nRear view camera: nope...but it\'s got a transparent rear window and you have a fucking neck that can turn. <br>\n<br>\nLet me tell you a story. One day my Corolla started making a strange sound. I didn\'t give a shit and ignored it. It went away. The End. <br>\n
br>\nFavorite food: spaghetti<br>\nFavorite tv show: Alf<br>\nFavorite band: tie between Bush and the Gin Blossoms<br>\n<br>\nThis car is as practical as a Roth IRA. It\'s as middle-of-the-road as your grandpa during his last Silver Alert. It\'s as utilitarian as a member of a church whose scripture is based entirely on water bills.<br>\n<br>\nWhen I ran the CarFax for this car, I got back a single piece of paper that said, "It\'s a Corolla. It\'s fine."<br>\n<br>\nLet\'s face the facts, this car isn\'t going to win any beauty contests, but neither are you. Stop lying to yourself and stop lying to your wife. This isn\'t the car you want, it\'s the car you deserve: The fucking 1999 Toyota Corolla.<br>\n<br>'},
#   'title': '1999 Toyota Corolla - Fine AF',
#   'title_detail': {'base': 'https://www.craigslist.org/about/best/all/index.rss',
#    'language': None,
#    'type': 'text/plain',
#    'value': '1999 Toyota Corolla - Fine AF'},
#   'updated': '2018-04-19T10:52:11-05:00',
#   'updated_parsed': time.struct_time(tm_year=2018, tm_mon=4, tm_mday=19, tm_hour=15, tm_min=52, tm_sec=11, tm_wday=3, tm_yday=109, tm_isdst=0)},
#  {'author': 'robot@craigslist.org',
#   'author_detail': {'email': 'robot@craigslist.org'},
#   'authors': [{'email': 'robot@craigslist.org'}],
#   'dc_source': 'https://www.craigslist.org/about/best/phi/6513230932.html',
#   'dc_type': 'text',
#   'id': 'https://www.craigslist.org/about/best/phi/6513230932.html',
#   'link': 'https://www.craigslist.org/about/best/phi/6513230932.html',
#   'links': [{'href': 'https://www.craigslist.org/about/best/phi/6513230932.html',
#     'rel': 'alternate',
#     'type': 'text/html'}],
#   'rights': 'copyright 2018 craigslist',
#   'rights_detail': {'base': 'https://www.craigslist.org/about/best/all/index.rss',
#    'language': None,
#    'type': 'text/plain',
#    'value': 'copyright 2018 craigslist'},
#   'summary': 'Selling 40 full-sized wax figures/vinyl in Amish wardrobe from the Amish Farm and House tourist attraction. Originally from the Lancaster Wax Museum in a barn raising scene.  Mostly all of them believed to be made by Dorfman Museum Figures out of Baltimore.  The infant has a stamp from a different manufacturer. <br>\nVarying sizes, ages and details on these figures. The wardrobe can be exchanged to suit your historical or theatrical needs. There are 5 female figures, 3 children figures, about 32 male figures and 1 dog. Five of the men are mechanical. The dog is mechanical as well. Varying conditions. The parts are removable and some are disassembled but can be assembled for viewing.$1500 for anamatronic figure, $350-For full-sized adults, $300-Children/Dog.  Hoping to sell as a set.  Only Reasonable offers and Serious Buyers Please.',
#   'summary_detail': {'base': 'https://www.craigslist.org/about/best/all/index.rss',
#    'language': None,
#    'type': 'text/html',
#    'value': 'Selling 40 full-sized wax figures/vinyl in Amish wardrobe from the Amish Farm and House tourist attraction. Originally from the Lancaster Wax Museum in a barn raising scene.  Mostly all of them believed to be made by Dorfman Museum Figures out of Baltimore.  The infant has a stamp from a different manufacturer. <br>\nVarying sizes, ages and details on these figures. The wardrobe can be exchanged to suit your historical or theatrical needs. There are 5 female figures, 3 children figures, about 32 male figures and 1 dog. Five of the men are mechanical. The dog is mechanical as well. Varying conditions. The parts are removable and some are disassembled but can be assembled for viewing.$1500 for anamatronic figure, $350-For full-sized adults, $300-Children/Dog.  Hoping to sell as a set.  Only Reasonable offers and Serious Buyers Please.'},
#   'title': 'Full Size Wax Figures Dressed in Amish Wardrobe-40 Different Sizes/Ages-Male/Fem',
#   'title_detail': {'base': 'https://www.craigslist.org/about/best/all/index.rss',
#    'language': None,
#    'type': 'text/plain',
#    'value': 'Full Size Wax Figures Dressed in Amish Wardrobe-40 Different Sizes/Ages-Male/Fem'},
#   'updated': '2018-02-28T10:25:57-05:00',
#   'updated_parsed': time.struct_time(tm_year=2018, tm_mon=2, tm_mday=28, tm_hour=15, tm_min=25, tm_sec=57, tm_wday=2, tm_yday=59, tm_isdst=0)},
#  {'author': 'robot@craigslist.org',
#   'author_detail': {'email': 'robot@craigslist.org'},
#   'authors': [{'email': 'robot@craigslist.org'}],
#   'dc_source': 'https://www.craigslist.org/about/best/det/6543142982.html',
#   'dc_type': 'text',
#   'id': 'https://www.craigslist.org/about/best/det/6543142982.html',
#   'link': 'https://www.craigslist.org/about/best/det/6543142982.html',
#   'links': [{'href': 'https://www.craigslist.org/about/best/det/6543142982.html',
#     'rel': 'alternate',
#     'type': 'text/html'}],
#   'rights': 'copyright 2018 craigslist',
#   'rights_detail': {'base': 'https://www.craigslist.org/about/best/all/index.rss',
#    'language': None,
#    'type': 'text/plain',
#    'value': 'copyright 2018 craigslist'},
#   'summary': "Hey there,<br>\n<br>\nMy friends and I were trying to figure out the craziest thing we could do on magic mushrooms and realized that watching a live child birth would be, by far, the most incredible, mind-blowing experience that we could think of.<br>\n<br>\nWe are looking for a woman with-child who would permit 5 respectful ~27 year old men to watch her give live birth, while on magic mushrooms.<br>\n<br>\nCompensation is negotiable, but for sure at least $100 pp and the knowledge of knowning that you just blew some peoples' mind, having a baby come out of you.<br>\n<br>\nThis offer may not be for everyone. If you know someone who may be interested, plase share this offer so that might fulfill our dream of watching a live birth on mushrooms.<br>\n<br>",
#   'summary_detail': {'base': 'https://www.craigslist.org/about/best/all/index.rss',
#    'language': None,
#    'type': 'text/html',
#    'value': "Hey there,<br>\n<br>\nMy friends and I were trying to figure out the craziest thing we could do on magic mushrooms and realized that watching a live child birth would be, by far, the most incredible, mind-blowing experience that we could think of.<br>\n<br>\nWe are looking for a woman with-child who would permit 5 respectful ~27 year old men to watch her give live birth, while on magic mushrooms.<br>\n<br>\nCompensation is negotiable, but for sure at least $100 pp and the knowledge of knowning that you just blew some peoples' mind, having a baby come out of you.<br>\n<br>\nThis offer may not be for everyone. If you know someone who may be interested, plase share this offer so that might fulfill our dream of watching a live birth on mushrooms.<br>\n<br>"},
#   'title': 'Want to watch a live birth on mushrooms',
#   'title_detail': {'base': 'https://www.craigslist.org/about/best/all/index.rss',
#    'language': None,
#    'type': 'text/plain',
#    'value': 'Want to watch a live birth on mushrooms'},
#   'updated': '2018-03-26T08:18:25-04:00',
#   'updated_parsed': time.struct_time(tm_year=2018, tm_mon=3, tm_mday=26, tm_hour=12, tm_min=18, tm_sec=25, tm_wday=0, tm_yday=85, tm_isdst=0)},
#  {'author': 'robot@craigslist.org',
#   'author_detail': {'email': 'robot@craigslist.org'},
#   'authors': [{'email': 'robot@craigslist.org'}],
#   'dc_source': 'https://www.craigslist.org/about/best/phi/6524792918.html',
#   'dc_type': 'text',
#   'id': 'https://www.craigslist.org/about/best/phi/6524792918.html',
#   'link': 'https://www.craigslist.org/about/best/phi/6524792918.html',
#   'links': [{'href': 'https://www.craigslist.org/about/best/phi/6524792918.html',
#     'rel': 'alternate',
#     'type': 'text/html'}],
#   'rights': 'copyright 2018 craigslist',
#   'rights_detail': {'base': 'https://www.craigslist.org/about/best/all/index.rss',
#    'language': None,
#    'type': 'text/plain',
#    'value': 'copyright 2018 craigslist'},
#   'summary': "1991 Mercedes-Benz 410D! <br>\nRemovable & Portable Russian bath sauna spa!<br>\n95 HP! <br>\n DIESEL!<br>\nCLEAN! RUNS DRIVES GREAT!<br>\n5-SPEED MANUAL TRANSMISSION!<br>\nNO RUST!<br>\nBRAND NEW TIRES!<br>\nAND MUCH MUCH MORE!<br>\nThe mileage on the title is exempt by Federal Law (Vehicles over 10 years and older) and the odometer reads 48,440 miles, which is 77,958 km as shown in the pics. <br>\nIMPORTED DIRECTLY FROM GERMANY!<br>\
detail': {'base': 'https://www.craigslist.org/about/best/all/index.rss',
#    'language': None,
#    'type': 'text/plain',
#    'value': 'Mercedes-Benz Sprinter DIESEL MANUAL SAUNA BANIA'},
#   'updated': '2018-03-09T16:52:52-05:00',
#   'updated_parsed': time.struct_time(tm_year=2018, tm_mon=3, tm_mday=9, tm_hour=21, tm_min=52, tm_sec=52, tm_wday=4, tm_yday=68, tm_isdst=0)},
#  {'author': 'robot@craigslist.org',
#   'author_detail': {'email': 'robot@craigslist.org'},
#   'authors': [{'email': 'robot@craigslist.org'}],
#   'dc_source': 'https://www.craigslist.org/about/best/mlb/6480376032.html',
#   'dc_type': 'text',
#   'id': 'https://www.craigslist.org/about/best/mlb/6480376032.html',
#   'link': 'https://www.craigslist.org/about/best/mlb/6480376032.html',
#   'links': [{'href': 'https://www.craigslist.org/about/best/mlb/6480376032.html',
#     'rel': 'alternate',
#     'type': 'text/html'}],
#   'rights': 'copyright 2018 craigslist',
#   'rights_detail': {'base': 'https://www.craigslist.org/about/best/all/index.rss',
#    'language': None,
#    'type': 'text/plain',
#    'value': 'copyright 2018 craigslist'},
#   'summary': "Gently used orbital rocket in good condition. Fully loaded with onboard flight computer, launch and landing hardware. Take off and land anywhere! 9X Merlin engines each capable of producing 200k lb.ft of thrust. Just fuel it up and it's ready to go. Says Falcon 9 on the body, slight burnt paint can be buffed out. <br>\n<br>\nMust bring own tug boat, no shipping. Asking $9,900,000 or best offer. Do not lowball, this is an orbital capable autonomous rocket. You will not find another one like it.<br>\n<br>\nSerious buyers only.<br>\n<br>",
#   'summary_detail': {'base': 'https://www.craigslist.org/about/best/all/index.rss',
#    'language': None,
#    'type': 'text/html',
#    'value': "Gently used orbital rocket in good condition. Fully loaded with onboard flight computer, launch and landing hardware. Take off and land anywhere! 9X Merlin engines each capable of producing 200k lb.ft of thrust. Just fuel it up and it's ready to go. Says Falcon 9 on the body, slight burnt paint can be buffed out. <br>\n<br>\nMust bring own tug boat, no shipping. Asking $9,900,000 or best offer. Do not lowball, this is an orbital capable autonomous rocket. You will not find another one like it.<br>\n<br>\nSerious buyers only.<br>\n<br>"},
#   'title': 'FS: Gently Used Orbital Launch Vehicle',
#   'title_detail': {'base': 'https://www.craigslist.org/about/best/all/index.rss',
#    'language': None,
#    'type': 'text/plain',
#    'value': 'FS: Gently Used Orbital Launch Vehicle'},
#   'updated': '2018-02-01T01:12:07-05:00',
#   'updated_parsed': time.struct_time(tm_year=2018, tm_mon=2, tm_mday=1, tm_hour=6, tm_min=12, tm_sec=7, tm_wday=3, tm_yday=32, tm_isdst=0)},
#  {'author': 'robot@craigslist.org',
#   'author_detail': {'email': 'robot@craigslist.org'},
#   'authors': [{'email': 'robot@craigslist.org'}],
#   'dc_source': 'https://www.craigslist.org/about/best/atl/6521329251.html',
#   'dc_type': 'text',
#   'id': 'https://www.craigslist.org/about/best/atl/6521329251.html',
#   'link': 'https://www.craigslist.org/about/best/atl/6521329251.html',
#   'links': [{'href': 'https://www.craigslist.org/about/best/atl/6521329251.html',
#     'rel': 'alternate',
#     'type': 'text/html'}],
#   'rights': 'copyright 2018 craigslist',
#   'rights_detail': {'base': 'https://www.craigslist.org/about/best/all/index.rss',
#    'language': None,
#    'type': 'text/plain',
#    'value': 'copyright 2018 craigslist'},
#   'summary': "Interested in work in the vast sewer industry here in Atlanta then you just got the lottery, I'm hiring helpers to do video inspections with sonar in large diameter sewer, will train and certify in confined space. Look at it this way everybody's got to eat, sleep, sh!t and die so there will always be a need for this type of work. If interested email resume<br>\n<br>",
#   'summary_detail': {'base': 'https://www.craigslist.org/about/best/all/index.rss',
#    'language': None,
#    'type': 'text/html',
#    'value': "Interested in work in the vast sewer industry here in Atlanta then you just got the lottery, I'm hiring helpers to do video inspections with sonar in large diameter sewer, will train and certify in confined space. Look at it this way everybody's got to eat, sleep, sh!t and die so there will always be a need for this type of work. If interested email resume<br>\n<br>"},
#   'title': 'Making dirty movies for the county',
#   'title_detail': {'base': 'https://www.craigslist.org/about/best/all/index.rss',
#    'language': None,
#    'type': 'text/plain',
#    'value': 

#     'rel': 'alternate',
#     'type': 'text/html'}],
#   'rights': 'copyright 2018 craigslist',
#   'rights_detail': {'base': 'https://www.craigslist.org/about/best/all/index.rss',
#    'language': None,
#    'type': 'text/plain',
#    'value': 'copyright 2018 craigslist'},
#   'summary': "You are studying osteology, but I think not in Philly.  You and your girlfriend admired the plastic dog skeleton on my porch, and you thought it was extremely amusing that its scapulae were on backwards.  We tried unsuccessfully to repair it.  If that's not enough for you to know I'm talking about you, then you will also remember that you identified a mysterious skull I found in the ocean. I forget now what kind of fish it's from, so please tell me again what it is, though this is not why I am trying to find you.  <br>\nYou may recall I mentioned a dead groundhog I buried last summer and that I was hoping to put its skeleton together somehow and I believe you two wanted to help.  I think I might see if it's sufficiently decomposed now to do this project.  If you're still interested, please get in touch.  <br>\nJust to be clear: This is a platonic request for help to reassemble the skeleton of a dead groundhog.<br>\n<br>\n<br>\n<br>\n<br>",
#   'summary_detail': {'base': 'https://www.craigslist.org/about/best/all/index.rss',
#    'language': None,
#    'type': 'text/html',
#    'value': "You are studying osteology, but I think not in Philly.  You and your girlfriend admired the plastic dog skeleton on my porch, and you thought it was extremely amusing that its scapulae were on backwards.  We tried unsuccessfully to repair it.  If that's not enough for you to know I'm talking about you, then you will also remember that you identified a mysterious skull I found in the ocean. I forget now what kind of fish it's from, so please tell me again what it is, though this is not why I am trying to find you.  <br>\nYou may recall I mentioned a dead groundhog I buried last summer and that I was hoping to put its skeleton together somehow and I believe you two wanted to help.  I think I might see if it's sufficiently decomposed now to do this project.  If you're still interested, please get in touch.  <br>\nJust to be clear: This is a platonic request for help to reassemble the skeleton of a dead groundhog.<br>\n<br>\n<br>\n<br>\n<br>"},
#   'title': 'Osteologist near Clark Park - w4w',
#   'title_detail': {'base': 'https://www.craigslist.org/about/best/all/index.rss',
#    'language': None,
#    'type': 'text/plain',
#    'value': 'Osteologist near Clark Park - w4w'},
#   'updated': '2017-10-15T13:12:12-04:00',
#   'updated_parsed': time.struct_time(tm_year=2017, tm_mon=10, tm_mday=15, tm_hour=17, tm_min=12, tm_sec=12, tm_wday=6, tm_yday=288, tm_isdst=0)},
#  {'author': 'robot@craigslist.org',
#   'author_detail': {'email': 'robot@craigslist.org'},
#   'authors': [{'email': 'robot@craigslist.org'}],
#   'dc_source': 'https://www.craigslist.org/about/best/vis/6326552375.html',
#   'dc_type': 'text',
#   'id': 'https://www.craigslist.org/about/best/vis/6326552375.html',
#   'link': 'https://www.craigslist.org/about/best/vis/6326552375.html',
#   'links': [{'href': 'https://www.craigslist.org/about/best/vis/6326552375.html',
#     'rel': 'alternate',
#     'type': 'text/html'}],
#   'rights': 'copyright 2018 craigslist',
#   'rights_detail': {'base': 'https://www.craigslist.org/about/best/all/index.rss',
#    'language': None,
#    'type': 'text/plain',
#    'value': 'copyright 2018 craigslist'},
#   'summary': "This is a 4 piece Beach Bowzer's Band on a Cabaret stage. Hasn't been used in a few years. Have Cyberamics Control System Parts Manual, Preventative Maintenance Program Outline, Tech Manual.  Tapes include Beach Bowzer's Ed Sullivan Cabaret,  Beagles #3 Cabaret, and Beach Bowzer's Diagnostics Cabaret. Tapes are dated 1985. Don't know how to operate. As is.<br>\n<br>",
#   'summary_detail': {'base': 'https://www.craigslist.org/about/best/all/index.rss',
#    'language': None,
#    'type': 'text/html',
#    'value': "This is a 4 piece Beach Bowzer's Band on a Cabaret stage. Hasn't been used in a few years. Have Cyberamics Control System Parts Manual, Preventative Maintenance Program Outline, Tech Manual.  Tapes include Beach Bowzer's Ed Sullivan Cabaret,  Beagles #3 Cabaret, and Beach Bowzer's Diagnostics Cabaret. Tapes are dated 1985. Don't know how to operate. As is.<br>\n<br>"},
#   'title': 'Vintage Chuck E Cheese Showbiz Pizza Animatronic Band w/ Stage',
#   'title_detail': {'base': 'https://www.craigslist.org/about/best/all/index.rss',
#    'language': None,
#    'type': 'text/plain',
#    'value': 
00',
#   'updated_parsed': time.struct_time(tm_year=2017, tm_mon=10, tm_mday=10, tm_hour=20, tm_min=51, tm_sec=59, tm_wday=1, tm_yday=283, tm_isdst=0)},
#  {'author': 'robot@craigslist.org',
#   'author_detail': {'email': 'robot@craigslist.org'},
#   'authors': [{'email': 'robot@craigslist.org'}],
#   'dc_source': 'https://www.craigslist.org/about/best/esh/6324690044.html',
#   'dc_type': 'text',
#   'id': 'https://www.craigslist.org/about/best/esh/6324690044.html',
#   'link': 'https://www.craigslist.org/about/best/esh/6324690044.html',
#   'links': [{'href': 'https://www.craigslist.org/about/best/esh/6324690044.html',
#     'rel': 'alternate',
#     'type': 'text/html'}],
#   'rights': 'copyright 2018 craigslist',
#   'rights_detail': {'base': 'https://www.craigslist.org/about/best/all/index.rss',
#    'language': None,
#    'type': 'text/plain',
#    'value': 'copyright 2018 craigslist'},
# ...
#   'title': 'To The Father Of My Husband',
#   'title_detail': {'base': 'https://www.craigslist.org/about/best/all/index.rss',
#    'language': None,
#    'type': 'text/plain',
#    'value': 'To The Father Of My Husband'},
#   'updated': '2017-08-02T20:32:34-07:00',
#   'updated_parsed': time.struct_time(tm_year=2017, tm_mon=8, tm_mday=3, tm_hour=3, tm_min=32, tm_sec=34, tm_wday=3, tm_yday=215, tm_isdst=0)},
#  {'author': 'robot@craigslist.org',
#   'author_detail': {'email': 'robot@craigslist.org'},
#   'authors': [{'email': 'robot@craigslist.org'}],
#   'dc_source': 'https://www.craigslist.org/about/best/brl/6230503426.html',
#   'dc_type': 'text',
#   'id': 'https://www.craigslist.org/about/best/brl/6230503426.html',
#   'link': 'https://www.craigslist.org/about/best/brl/6230503426.html',
#   'links': [{'href': 'https://www.craigslist.org/about/best/brl/6230503426.html',
#     'rel': 'alternate',
#     'type': 'text/html'}],
#   'rights': 'copyright 2018 craigslist',
#   'rights_detail': {'base': 'https://www.craigslist.org/about/best/all/index.rss',
#    'language': None,
#    'type': 'text/plain',
#    'value': 'copyright 2018 craigslist'},
#   'summary': "Vermonters, please understand the following: <br>\n<br>\nA STUDIO IS NOT A 1 BEDROOM. <br>\n<br>\n1 BEDROOM IS NOT A STUDIO. <br>\n<br>\nSTUDIOS ARE EFFICIENCIES AND SHOULD NEVER BE LISTED OR DESCRIBED AS A 1 BEDROOM. <br>\n<br>\nA 1 BEDROOM MEANS A SEPERATE ROOM BIGGER THAN A CLOSET INTENDED TO BE A BEDROOM AND HAS A DOOR THAT CLOSES.<br>\n<br>\nIF THE UNIT YOU'RE ADVERTISING DOES NOT HAVE THIS seperate ROOM, ISOLATED FROM THE REST OF THE APARTMENT, IT IS NOT A 1 BEDROOM. IT IS A STUDIO, WHICH IS NOT A 1 BEDROOM. <br>\n<br>\nALSO, A STUDIO IS NOT A 1 BEDROOM. <br>\n<br>\nALSO, A 1 BEDROOM IS NOT A STUDIO. <br>\n<br>\nPlease, for the love of everything in the world, stop posting studios as a 1 bedroom. Just because a person sleeps in that space does not mean it's a 1 bedroom. It's still a studio, even if someone sleeps in it, if it's not a seperate room with a door. <br>\n<br>\nPop Quiz: <br>\n<br>\nIs a studio a 1 bedroom as well? <br>\n<br>\n...<br>\n<br>\n....<br>\n<br>\n......<br>\n<br>\nYou should know the answer now. Go ahead, say it with me: <br>\n<br>\nA STUDIO IS NOT A 1 BEDROOM. <br>\n<br>\nThanks.<br>\n<br>",
#   'summary_detail': {'base': 'https://www.craigslist.org/about/best/all/index.rss',
#    'language': None,
#    'type': 'text/html',
#    'value': "Vermonters, please understand the following: <br>\n<br>\nA STUDIO IS NOT A 1 BEDROOM. <br>\n<br>\n1 BEDROOM IS NOT A STUDIO. <br>\n<br>\nSTUDIOS ARE EFFICIENCIES AND SHOULD NEVER BE LISTED OR DESCRIBED AS A 1 BEDROOM. <br>\n<br>\nA 1 BEDROOM MEANS A SEPERATE ROOM BIGGER THAN A CLOSET INTENDED TO BE A BEDROOM AND HAS A DOOR THAT CLOSES.<br>\n<br>\nIF THE UNIT YOU'RE ADVERTISING DOES NOT HAVE THIS seperate ROOM, ISOLATED FROM THE REST OF THE APARTMENT, IT IS NOT A 1 BEDROOM. IT IS A STUDIO, WHICH IS NOT A 1 BEDROOM. <br>\n<br>\nALSO, A STUDIO IS NOT A 1 BEDROOM. <br>\n<br>\nALSO, A 1 BEDROOM IS NOT A STUDIO. <br>\n<br>\nPlease, for the love of everything in the world, stop posting studios as a 1 bedroom. Just because a person sleeps in that space does not mean it's a 1 bedroom. It's still a studio, even if someone sleeps in it, if it's not a seperate room with a door. <br>\n<br>\nPop Quiz: <br>\n<br>\nIs a studio a 1 bedroom as well? <br>\n<br>\n...<br>\n<br>\n....<br>\n<br>\n......<br>\n<br>\nYou should know the answer now. Go ahead, say it with me: <br>\n<br>\nA STUDIO IS NOT A 1 BEDROOM. <br>\n<br>\nThanks.<br>\n<br>"},
#   'title': 'An Open Letter To All Posting In Housing',
#   'title_detail': {'base': 'https://www.craigslist.org/about/best/all/index.rss',
#    'language': None,
#    'type': 'text/plain',
#    'value': 'An Open Letter To All Posting In Housing'},
#   'updated': '2017-07-22T03:16:37-04:00',
#   'updated_parsed': time.struct_time(tm_year=2017, tm_mon=7, tm_mday=22, tm_hour=7, tm_min=16, tm_sec=37, tm_wday=5, tm_yday=203, tm_isdst=0)},
#  {'author': 'robot@craigslist.org',
#   'author_detail': {'email': 'robot@craigslist.org'},
#   'authors': [{'email': 'robot@craigslist.org'}],
#   'dc_source': 'https://www.craigslist.org/about/best/chi/6216723045.html',
#   'dc_type': 'text',
#   'id': 'https://www.craigslist.org/about/best/chi/6216723045.html',
#   'link': 'https://www.craigslist.org/about/best/chi/6216723045.html',
#   'links': [{'href': 'https://www.craigslist.org/about/best/chi/6216723045.html',
#     'rel': 'alternate',
#     'type': 'text/html'}],
#   'rights': 'copyright 2018 craigslist',
#   'rights_detail': {'base': 'https://www.craigslist.org/about/best/all/index.rss',
#    'language': None,
#    'type': 'text/plain',
#    'value': 'copyright 2018 craigslist'},
#   'summary': 'Would you like to wow friends and family with your uncanny Tom Cruise impersonation?<br>\n<br>\nNow you can learn how to be Tom Cruise, in just one afternoon! A PROFESSIONAL Tom Cruise impersonator is developing a one-hour crash course where you can learn to do YOUR OWN impression of the TOP GUN star. He needs "beta testers" who are eager to learn the tricks of the Tom-Cruise-impersonator trade.<br>\n<br>\nALL genders/body types/ethnicities are welcome. You don\'t have to look like Tom!<br>\n<br>\nThe class will be filmed for review. Participants will be given footage for their participation in this trial run of the "Learn To Be Tom Cruise" session.<br>\n<br>\nPlease reply with the following:<br>\n<br>\nName<br>\nAge <br>\nPhoto<br>\nEmail address<br>\nPhone number (and best times to reach you)<br>\nAND a sentence or two about why you want to BE LIKE TOM CRUISE!<br>\n<br>',
#   'summary_detail': {'base': 'https://www.craigslist.org/about/best/all/index.rss',
#    'language': None,
#    'type': 'text/html',
#    'value': 'Would you like to wow friends and family with your uncanny Tom Cruise impersonation?<br>\n<br>\nNow you can learn how to be Tom Cruise, in just one afternoon! A PROFESSIONAL Tom Cruise impersonator is developing a one-hour crash course where you can learn to do YOUR OWN impression of the TOP GUN star. He needs "beta testers" who are eager to learn the tricks of the Tom-Cruise-impersonator trade.<br>\n<br>\nALL genders/body types/ethnicities are welcome. You don\'t have to look like Tom!<br>\n<br>\nThe class will be filmed for review. Participants will be given footage for their participation in this trial run of the "Learn To Be Tom Cruise" session.<br>\n<br>\nPlease reply with the following:<br>\n<br>\nName<br>\nAge <br>\nPhoto<br>\nEmail address<br>\nPhone number (and best times to reach you)<br>\nAND a sentence or two about why you want to BE LIKE TOM CRUISE!<br>\n<br>'},
#   'title': 'Learn to impersonate Tom Cruise!',
#   'title_detail': {'base': 'https://www.craigslist.org/about/best/all/index.rss',
#    'language': None,
#    'type': 'text/plain',
#    'value': 'Learn to impersonate Tom Cruise!'},
#   'updated': '2017-07-12T16:18:19-05:00',
#   'updated_parsed': time.struct_time(tm_year=2017, tm_mon=7, tm_mday=12, tm_hour=21, tm_min=18, tm_sec=19, tm_wday=2, tm_yday=193, tm_isdst=0)},
#  {'author': 'robot@craigslist.org',
#   'author_detail': {'email': 'robot@craigslist.org'},
#   'authors': [{'email': 'robot@craigslist.org'}],
#   'dc_source': 'https://www.craigslist.org/about/best/dal/6198009200.html',
#   'dc_type': 'text',
#   'id': 'https://www.craigslist.org/about/best/dal/6198009200.html',
#   'link': 'https://www.craigslist.org/about/best/dal/6198009200.html',
#   'links': [{'href': 'https://www.craigslist.org/about/best/dal/6198009200.html',
#     'rel': 'alternate',
#     'type': 'text/html'}],
#   'rights': 'copyright 2018 craigslist',
#   'rights_detail': {'base': 'https://www.craigslist.org/about/best/all/index.rss',
#    'language': None,
#    'type': 'text/plain',
#    'value': 'copyright 2018 craigslist'},
#   'summary': "Cadillac Deville Smoker<br>\nONE OF A KIND!!!!!<br>\nThis is an custom homemade BBQ trailer grill. 1988 Cadillac Deville Smoker weight 2600 capacity 1300 heavy duty &amp; gagged steel great for parties, weddings or family unions. Has it's own hitch to pull anywhere. Great investment! SERIOUS buyers only!!!<br>\nThank you!!!!<br>",
#   'summary_detail': {'base': 'https://www.craigslist.org/about/best/all/index.rss',
#    'language': None,
#    'type': 'text/html',
#    'value': "Cadillac Deville Smoker<br>\nONE OF A KIND!!!!!<br>\nThis is an custom homemade BBQ trailer grill. 1988 Cadillac Deville Smoker weight 2600 capacity 1300 heavy duty &amp; gagged steel great for parties, weddings or family unions. Has it's own hitch to pull anywhere. Great investment! SERIOUS buyers only!!!<br>\nThank you!!!!<br>"},
#   'title': 'Cadillac DeVille SMOKER!',
#   'title_detail': {'base': 'https://www.craigslist.org/about/best/all/index.rss',
#    'language': None,
#    'type': 'text/plain',
#    'value': 'Cadillac DeVille SMOKER!'},
#   'updated': '2017-06-29T13:33:13-05:00',
#   'updated_parsed': time.struct_time(tm_year=2017, tm_mon=6, tm_mday=29, tm_hour=18, tm_min=33, tm_sec=13, tm_wday=3, tm_yday=180, tm_isdst=0)},
#  {'author': 'robot@craigslist.org',
#   'author_detail': {'email': 'robot@craigslist.org'},
#   'authors': [{'email': 'robot@craigslist.org'}],
#   'dc_source': 'https://www.craigslist.org/about/best/phx/6100073306.html',
#   'dc_type': 'text',
#   'id': 'https://www.craigslist.org/about/best/phx/6100073306.html',
#   'link': 'https://www.craigslist.org/about/best/phx/6100073306.html',
#   'links': [{'href': 'https://www.craigslist.org/about/best/phx/6100073306.html',
#     'rel': 'alternate',
#     'type': 'text/html'}],
#   'rights': 'copyright 2018 craigslist',
#   'rights_detail': {'base': 'https://www.craigslist.org/about/best/all/index.rss',
#    'language': None,
#    'type': 'text/plain',
#    'value': 'copyright 2018 craigslist'},
#   'summary': "Free 18' Sailboat. Grandpa was a sailor, missed the open water and so he hired a crane to drop a sailboat in his swimming pool. Time to get the boat out. Free to anyone who can remove the boat without damaging the block wall or landscaping. Serious inquires only. No trailer, no boom, no sails or rigging. Rudder? Yes. Still free. Thank you.<br>\n<br>",
#   'summary_detail': {'base': 'https://www.craigslist.org/about/best/all/index.rss',
#    'language': None,
#    'type': 'text/html',
#    'value': "Free 18' Sailboat. Grandpa was a sailor, missed the open water and so he hired a crane to drop a sailboat in his swimming pool. Time to get the boat out. Free to anyone who can remove the boat without damaging the block wall or landscaping. Serious inquires only. No trailer, no boom, no sails or rigging. Rudder? Yes. Still free. Thank you.<br>\n<br>"},
#   'title': "Free 18' Sailboat",
#   'title_detail': {'base': 'https://www.craigslist.org/about/best/all/index.rss',
#    'language': None,
#    'type': 'text/plain',
#    'value': "Free 18' Sailboat"},
#   'updated': '2017-04-22T16:33:19-07:00',
#   'updated_parsed': time.struct_time(tm_year=2017, tm_mon=4, tm_mday=22, tm_hour=23, tm_min=33, tm_sec=19, tm_wday=5, tm_yday=112, tm_isdst=0)},
#  {'author': 'robot@craigslist.org',
#   'author_detail': {'email': 'robot@craigslist.org'},
#   'authors': [{'email': 'robot@craigslist.org'}],
#   'dc_source': 'https://www.craigslist.org/about/best/cle/6147468220.html',
#   'dc_type': 'text',
#   'id': 'https://www.craigslist.org/about/best/cle/6147468220.html',
#   'link': 'https://www.craigslist.org/about/best/cle/6147468220.html',
#   'links': [{'href': 'https://www.craigslist.org/about/best/cle/6147468220.html',
#     'rel': 'alternate',
#     'type': 'text/html'}],
#   'rights': 'copyright 2018 craigslist',
#   'rights_detail': {'base': 'https://www.craigslist.org/about/best/all/index.rss',
#    'language': None,
#    'type': 'text/plain',
#    'value': 'copyright 2018 craigslist'},
#   'summary': 'GROW YOUR OWN BEER GARDEN !<br>\n<br>\nBeer seeds available for purchase. SPRING SPECIAL - 10 for $5.00 !<br>\n<br>\nPick-up in Lakewood or shipping available.<br>\n<br>\nEmail for more info.<br>\n<br>\nHave a great day !<br>\n(results not typical but fun to try)<br>\n<br>',
#   'summary_detail': {'base': 'https://www.craigslist.org/about/best/all/index.rss',
#    'language': None,
#    'type': 'text/html',
#    'value': 'GROW YOUR OWN BEER GARDEN !<br>\n<br>\nBeer seeds available for purchase. SPRING SPECIAL - 10 for $5.00 !<br>\n<br>\nPick-up in Lakewood or shipping available.<br>\n<br>\nEmail for more info.<br>\n<br>\nHave a great day !<br>\n(results not typical but fun to try)<br>\n<br>'},
#   'title': 'BEER SEEDS',
#   'title_detail': {'base': 'https://www.craigslist.org/about/best/all/index.rss',
#    'language': None,
#    'type': 'text/plain',
#    'value': 'BEER SEEDS'},
#   'updated': '2017-05-25T13:11:06-04:00',
#   'updated_parsed': time.struct_time(tm_year=2017, tm_mon=5, tm_mday=25, tm_hour=17, tm_min=11, tm_sec=6, tm_wday=3, tm_yday=145, tm_isdst=0)},
#  {'author': 'robot@craigslist.org',
#   'author_detail': {'email': 'robot@craigslist.org'},
#   'authors': [{'email': 'robot@craigslist.org'}],
#   'dc_source': 'https://www.craigslist.org/about/best/sea/6088811200.html',
#   'dc_type': 'text',
#   'id': 'https://www.craigslist.org/about/best/sea/6088811200.html',
#   'link': 'https://www.craigslist.org/about/best/sea/6088811200.html',
#   'links': [{'href': 'https://www.craigslist.org/about/best/sea/6088811200.html',
#     'rel': 'alternate',
#     'type': 'text/html'}],
#   'rights': 'copyright 2018 craigslist',
#   'rights_detail': {'base': 'https://www.craigslist.org/about/best/all/index.rss',
#    'language': None,
#    'type': 'text/plain',
#    'value': 'copyright 2018 craigslist'},
#   'summary': "Do you like to get down and dirty around decay? Do you wanna fuck among some fungi? The title says it all. I'm just a cold babe livin a moldy bedroom lookin for a lady. The jury's out on whether or not this musty love nest might be hazardous, but what's the fun in doin it without a little danger? The mattress isn't directly on the composting carpet so while you won't be manhandling the mildew, you'll still be having sex while swimming in spores.<br>\nYou bring a jacket, I'll make a mix tape. I'm hot to trot and surrounded by rot.<br>\n<br>",
#   'summary_detail': {'base': 'https://www.craigslist.org/about/best/all/index.rss',
#    'language': None,
#    'type': 'text/html',
#    'value': "Do you like to get down and dirty around decay? Do you wanna fuck among some fungi? The title says it all. I'm just a cold babe livin a moldy bedroom lookin for a lady. The jury's out on whether or not this musty love nest might be hazardous, but what's the fun in doin it without a little danger? The mattress isn't directly on the composting carpet so while you won't be manhandling the mildew, you'll still be having sex while swimming in spores.<br>\nYou bring a jacket, I'll make a mix tape. I'm hot to trot and surrounded by rot.<br>\n<br>"},
#   'title': 'Does mold turn you on? - w4w',
#   'title_detail': {'base': 'https://www.craigslist.org/about/best/all/index.rss',
#    'language': None,
#    'type': 'text/plain',
#    'value': 'Does mold turn you on? - w4w'},
#   'updated': '2017-04-14T17:03:50-07:00',
#   'updated_parsed': time.struct_time(tm_year=2017, tm_mon=4, tm_mday=15, tm_hour=0, tm_min=3, tm_sec=50, tm_wday=5, tm_yday=105, tm_isdst=0)}]

# %%
def calcMostFreaq(vocabList, fullText):
    import operator
    freqDict = {}
    for token in vocabList:
        freqDict[token] = fullText.count(token)
    sortedFreq = sorted(freqDict.items(), key=operator.itemgetter(1), reverse=True)
    return sortedFreq[:30]

# %%
def localWords(feed1, feed0):
    import feedparser
    docList = []
    classList = []
    fullText = []
    minLen = min(len(feed1['entries']), len(feed0['entries']))
    for i in range(minLen):
        wordList = textParse(feed1['entries'][i]['summary'])
        docList.append(wordList)
        fullText.extend(wordList)
        classList.append(1)
        wordList = textParse(feed0['entries'][i]['summary'])
        docList.append(wordList)
        fullText.extend(wordList)
        classList.append(0)
    vocaList = createVocabList(docList)
    top30Words = calcMostFreaq(vocaList, fullText)
    for pairW in top30Words:
        # 去掉次数最高的词
        if pairW[0] in vocaList:
            vocaList.remove(pairW[0])
    trainingSet = list(range(2*minLen))
    testSet = []
    for i in range(5):
        randIndex = int(np.random.uniform(0, len(trainingSet)))
        testSet.append(trainingSet[randIndex])
        del trainingSet[randIndex]
    trainMat = []
    trainClasses = []
    for docIndex in trainingSet:
        trainMat.append(bagOfWordVecMN(vocaList, docList[docIndex]))
        trainClasses.append(classList[docIndex])
    p0V, p1V, pSpam = trainNB0(np.array(trainMat), np.array(trainClasses))
    errorCount = 0
    for docIndex in testSet:
        wordVector = bagOfWordVecMN(vocaList, docList[docIndex])
        if classifyNB(np.array(wordVector), p0V, p1V, pSpam) != classList[docIndex]:
            errorCount += 1
    print('the error rate is: {}'.format(errorCount/len(testSet)))
    return vocaList, p0V, p1V

# %%
ny = feedparser.parse('https://newyork.craigslist.org/search/res?format=rss')
sf = feedparser.parse('https://sfbay.craigslist.org/search/apa?format=rss')
vocabList, pSF, pNY = localWords(ny, sf)
# Out:
# the error rate is: 0.0
# E:\Anaconda3\lib\re.py:212: FutureWarning: split() requires a non-empty pattern match.
#   return _compile(pattern, flags).split(string, maxsplit)

# %% [markdown]
# ### 6.2 分析数据：显示地域相关的用词

# %%
def getTopWords(ny, sf):
    import operator
    vocabList, p0V, p1V = localWords(ny, sf)
    vocabList = list(vocabList)
    topNY = []
    topSF = []
    for i in range(len(p0V)):
        if p0V[i] > -6.0:
            topSF.append((vocabList[i], p0V[i]))
        if p1V[i] > -6.0:
            topNY.append((vocabList[i], p1V[i]))
    sortedSF = sorted(topSF, key=lambda pair: pair[1], reverse=True)
    print('SF**SF**SF**SF**SF**SF**SF**SF**SF**SF')
    for item in sortedSF:
        print(item[0])
    sortedNY = sorted(topNY, key=lambda pair: pair[1], reverse=True)
    print('NY**NY**NY**NY**NY**NY**NY**NY**NY**NY')
    for item in sortedNY:
        print(item[0])

# %%
getTopWords(ny, sf)
# Out:
# the error rate is: 0.0
# SF**SF**SF**SF**SF**SF**SF**SF**SF**SF
# water
# garbage
# bath
# bedrooms
# 5
# location
# floor
# great
# newly
# hardwood
# floors
# family
# refrigerator
# building
# bathroom
# this
# park
# updated
# house
# room
# renovated
# full
# rent
# remodeled
# stove
# access
# over
# walk
# space
# on
# single
# 3
# sq
# shower
# street
# 10
# located
# high
# spacious
# ft
# tub
# car
# features
# dishwasher
# easy
# apartment
# gas
# living
# appliances
# recently
# neighborhood
# garage
# group
# story
# pays
# meder
# end
# range
# large
# washer
# sf
# 280
# available
# flooring
# details
# owner
# storage
# gate
# baths
# first
# entertainment
# 2nd
# disposal
# ca
# parking
# grocery
# stores
# nine
# private
# has
# requirements
# beautiful
# closet
# copy
# near
# schools
# distance
# w
# incl
# eat
# included
# garden
# granite
# all
# month
# pane
# walking
# text
# steam
# heat
# at
# furnished
# apartments
# electric
# appliance
# dryer
# tops
# cdl
# kitchens
# lots
# now
# windows
# bathrooms
# charming
# 101
# downtown
# freeways
# site
# dan
# verifiable
# your
# bay
# ready
# luxury
# appointment
# level
# dinner
# small
# areas
# oven
# 850
# nobel
# me
# modern
# 500
# combo
# winning
# call
# creek
# c
# year
# 2018
# flat
# heart
# credit
# 2200
# disposals
# bridge
# 3250
# plan
# bed
# appeal
# separate
# email
# city
# sterling
# george
# touches
# 94559
# beginning
# 87
# supermarkets
# that
# vaulted
# leasing
# golden
# hand
# us
# very
# close
# chandelier
# milpitas
# m
# university
# feet
# below
# designer
# public
# center
# cottage
# be
# dual
# backyard
# 2bedroom
# from
# popular
# major
# amcllc
# respond
# hi
# clara
# also
# cow
# ucsc
# villas
# couple
# made
# hollow
# upscale
# interior
# conveniently
# friend
# pet
# unique
# build
# pittsburg
# per
# highlights
# ranch
# pay
# fast
# desk
# 1070
# report
# master
# 2000
# huge
# freshly
# sqft
# diamond
# gated
# san
# comes
# homes
# quiet
# convenient
# across
# about
# x
# fire
# francisco
# 00
# style
# st
# garaged
# 2625
# hillside
# many
# employment
# exterior
# back
# come
# fireplace
# net
# banking
# 383
# steel
# delightful
# d
# friday
# least
# open
# 1622
# laminated
# time
# monthly
# showings
# heater
# cha
# bbq
# napa
# condo
# hill
# double
# independent
# use
# danbury
# light
# ceiling
# moore
# restaurants
# yards
# minutes
# long
# meritage
# august
# extra
# inside
# front
# 1320
# will
# laundry
# marina
# 1156
# preserve
# award
# convenience
# highway
# upgrades
# 2b2b
# saturday
# owners
# flair
# microwave
# views
# special
# 880
# include
# packages
# someone
# units
# nice
# 1248
# microwaves
# approximately
# transportation
# kids
# no
# square
# address
# ceilings
# dining
# blvd
# offers
# divide
# formal
# ins
# more
# a5xz51
# lombard
# 2bathrooms
# verifi
# russian
# remod
# pantry
# fully
# al
# kitch
# california
# detached
# painted
# includes
# move
# pol
# stainless
# 2330
# rail
# 3bedrooms
# shared
# deck
# bookshelves
# counter
# http
# samtra
# take
# it
# plus
# santa
# off
# asap
# see
# studio
# borders
# link
# closets
# amenities
# tile
# lease
# finishes
# NY**NY**NY**NY**NY**NY**NY**NY**NY**NY
# have
# as
# help
# service
# estate
# real
# if
# an
# seeking
# at
# work
# field
# need
# well
# customer
# management
# currently
# no
# experienced
# free
# me
# available
# skills
# m
# ap
# willing
# com
# detail
# property
# young
# assistant
# salesforce
# excellent
# employment
# construction
# time
# data
# environment
# individual
# hire
# overall
# best
# coach
# administrative
# months
# within
# professional
# it
# on
# getting
# your
# towards
# ready
# 900
# licensed
# soccer
# county
# does
# english
# 18
# writing
# that
# recruiters
# then
# spare
# e
# profile
# orie
# anything
# type
# their
# feel
# strong
# michael
# response
# sex
# excel
# also
# based
# digital
# been
# live
# salary
# nudity
# events
# pay
# make
# private
# are
# requirements
# job
# deadline
# back
# this
# parties
# rent
# thank
# business
# driven
# college
# immediate
# not
# promise
# hr
# involve
# media
# text
# someone
# tutoring
# expert
# ve
# bartender
# fully
# qualified
# personal
# plenty
# lend
# services
# clean
# etc
# retail
# positions
# campaign
# launch
# certification
# ms
# caring
# level
# account
# small
# without
# large
# columbian
# attending
# cocktail
# call
# existing
# lqps
# tour
# option
# gigs
# starter
# tokens
# y7dxi
# helping
# product
# sets
# maria
# vlookups
# webcams
# works
# effectively
# https
# who
# creative
# 3
# highly
# upon
# effort
# other
# student
# examples
# track
# bartend
# businesses
# manager
# provide
# drinks
# references
# amicably
# dedicated
# smith
# copywriter
# model
# certified
# merchant
# don
# injury
# public
# team
# teams
# charts
# tables
# doing
# oriented
# software
# request
# sign
# placement
# xanthea
# commun
# default
# instagram
# gt
# attention
# player
# into
# provided
# block
# self
# sales
# t
# rangel
# room
# degree
# chaturbate
# office
# own
# what
# build
# independently
# decent
# watch
# regards
# org
# fast
# interested
# content
# ny
# proofreading
# scored
# able
# working
# paralegal
# re
# has
# pivot
# relat
# fashion
# clientele
# summary
# full
# versed
# organizations
# s
# trying
# modeling
# technology
# many
# museum
# statements
# specializing
# b
# points
# students
# creation
# friday
# flourish
# formulas
# queengoddessx
# york
# video
# capture
# bfa
# alcohol
# sunday
# put
# costs
# part
# possible
# projects
# editing
# use
# 8
# social
# commissions
# tools
# board
# ad
# spreadsheets
# long
# seo
# interpersonal
# written
# clients
# spread
# all
# low
# because
# analysis
# marketing
# will
# ok
# teaching
# aide
# creating
# cindy
# traditional
# run
# gives
# knowledge
# trained
# visual
# westchester
# but
# saturday
# prices
# regions
# go
# include
# relati
# subject
# resume
# intr
# organizer
# efficient
# person
# admin
# summer
# institute
# punctual
# poor
# reading
# communication
# graphs
# do
# bar
# hello
# old
# courteous
# page
# 70459149
# sessions
# review
# refer
# damage
# elderly
# cloud
# let
# prompt
# verbal
# 23
# they
# any
# classic
# earn
# nyc
# jobs
# analyze
# its
# commerce
# now
# production
# strategic
# taught
# take
# out
# advanced
# like
# fairfield
# link
# teacher
# essays
# reports
# mainly
# up
# camps
# liability
# offer
# 11
# along
# E:\Anaconda3\lib\re.py:212: FutureWarning: split() requires a non-empty pattern match.
#   return _compile(pattern, flags).split(string, maxsplit)

# %% [markdown]
# > 对于分类而言，使用概率又是要比使用硬规则更为有效。
#
# > 朴素贝叶斯的特征之间独立性假设降低对数据量的需求，已经可以取得很好的效果。
#
# > 概率取对数、词袋模型以及移除停用词都是常用技巧。
